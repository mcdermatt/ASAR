# %%
from divide import divide
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import numpy as np

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2
# %autosave 180
# %matplotlib notebook
# Out:
# Autosaving every 180 seconds
# Autosaving every 180 seconds

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.set_xlim([-10,10])
ax.set_ylim([-10,10])



D = divide(fig, ax, n = 50)
# Out:
# created grid with 121 voxels
# created grid with 121 voxels

# %%
test = np.linspace(1,10,10)[:,None]
test = np.append(test, test, axis = 1)
test[3:, 1] = 3 
print(test)

t = (test == np.array([3,3]))
# print(t)

a = t.all(axis = 1)

arg = np.where(a == True)
print(arg)
print(test[arg])

# %%
print(np.__doc__)
