# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
# n trials on same set of 2 frames (sensor noise re-applied and initial conds randomized for each trial)

#part 1--------------------------
# # with extended surface mitigation
# fn1 = "MC_results/scene1_ICET_estimates_v4.npy" 
# fn2 = "MC_results/scene1_ICET_pred_stds_v4.npy"
# # v4 = 500 trials @ 5iter, v5 = 50 trials @ 10 iter, 
# # v6 = 1000 trials, v7 = 2500 trials, fid=80

#no extended surface mitigation
fn1 = "MC_results/scene1_ICET_estimates_NM_v5.npy" 
fn2 = "MC_results/scene1_ICET_pred_stds_NM_v5.npy"
# #v3=500 trials with 5 iter, v4=500 trials with 
#---------------------------------

# #part 2---------------------------
# # with extended surface mitigation
# fn1 = "MC_results/scene2_ICET_estimates_v3.npy" 
# fn2 = "MC_results/scene2_ICET_pred_stds_v3.npy"
# # v1 = 500, v2 = 50 test, v3 -= 500 (best), v4 and v5 = test

# # # #no extended surface mitigation
# # fn1 = "MC_results/scene2_ICET_estimates_NM_v5.npy" 
# # fn2 = "MC_results/scene2_ICET_pred_stds_NM_v5.npy"
# #v1 = 500, v2 = 50 test, v3=500 (best)
# #---------------------------------

# #part 3-------------------------
# # with extended surface mitigation
# # fn1 = "MC_results/scene3_ICET_estimates_v1.npy" 
# # fn2 = "MC_results/scene3_ICET_pred_stds_v1.npy"

# # # #no extended surface mitigation
# fn1 = "MC_results/scene3_ICET_estimates_NM_v1.npy" 
# fn2 = "MC_results/scene3_ICET_pred_stds_NM_v1.npy"
# #---------------------------------

est = np.load(fn1)
print(np.shape(est))
pred_stds = np.load(fn2)

print("\n Predicted RMSE: \n", np.mean(pred_stds, axis = 0)[:3], np.rad2deg(np.mean(pred_stds, axis = 0)[3:]))
# print("\n mean: \n", np.mean(est, axis=0)) 
# print(np.std(pred_stds, axis = 0)) #shows consistant prediction for soln std for constant scene
# Out:
# (150, 6)
#
#  Predicted RMSE:
#  [0.00058728 0.00016623 0.00010206] [0.00121278 0.00121822 0.00085007]

# %%
#calculate RMSE
RMSE_trans = np.sqrt(np.mean((est[:,:3]**2), axis = 0))[:3]
RMSE_rot = np.sqrt(np.mean((np.rad2deg(est[:,3:])**2), axis = 0))
print("\n Actual RMSE: \n", RMSE_trans, RMSE_rot)
# print("\n actual STD: \n", np.std(est[:,:3], axis=0), np.std(np.rad2deg(est[:,3:]), axis=0))
# Out:
#  Actual RMSE:
#  [1.29888642e-01 1.89008652e-04 1.17455660e-04] [0.00125869 0.0016236  0.0009308 ]

# %%
#remove outliers from est

# # #vertical axis
ok = np.where(abs(est[:,2]) < 0.0005)
est = est[ok]
# #roll
ok3 = np.where(abs(est[:,3]) < 0.000058)
est = est[ok3]
#pitch
ok4 = np.where(abs(est[:,4]) < 0.000067)
est = est[ok4]
#yaw
ok5 = np.where(abs(est[:,5]) < 0.0000476)
est = est[ok5]

#calc mean and std
mean = np.mean(est, axis = 0)
print(mean, "\n")
std = np.std(est, axis = 0)
std[3:] = np.rad2deg(std[3:]) #convert angles to degrees
std += np.abs(mean) #add in any net offset

print(std)
# Out:
# [-5.93756331e-06  7.40150194e-04  7.90155020e-06  9.26697526e-07
#   1.70490101e-06 -1.18228845e-06]
#
# [0.00012398 0.00582379 0.00015223 0.00131668 0.00184127 0.0013059 ]

# %%
#for debug - plot pred_stds to make sure we don't have any outlier trials
fig, ax = plt.subplots()

# ax.plot(pred_stds[:,2])

ax.plot(est[:,2]) 
# ax.plot(np.rad2deg(est[:,4]))

ok = np.where(abs(est[:,2]) < 0.0003)
# ok = np.where(abs(est[:,2]) < 0.1)

# print(ok)
print(np.std(est[ok], axis = 0)[:3])
print(np.rad2deg(np.std(est[ok], axis = 0))[3:])
# Out:
# <img src="data:image/png;base64,..." width="640">
# [1.05924315e-01 1.87139106e-04 9.32674498e-05]
# [0.00121443 0.00138415 0.00094987]

# %%
bad = np.where(est[:,0] > -0.35)
print(bad)
print(est)
