# %% [markdown]
# # Perspective Shift Identification

# %% [markdown]
# ### Goal:
# Use ML to identify perspective shift in movement of distribution centers

# %% [markdown]
# ![Perspective%20Shift%201.png](attachment:Perspective%20Shift%201.png)

# %% [markdown]
# ### Assumptions:
# Gross rotation and translation have already been estimated by previous scan matching iterations
#
# ### Network structure:
# Inputs:
# xyz of 25 points randomly sampled from each distribution
#
# Output:
# Correction factor translation between the two centers

# %% [markdown]
# ### Training data generation
#
# (starting with toy example)
#
# 1- generate grid of simple shapes in Inventor
#
# 2- Rotate randomly, translate randomly and simulate lidar scan of shapes at 2 points in time using MatLab script
#
# 3- Sample 25 points from each object and save to file. Also store information on rotation and translation to seperate file
#
# 4- import data here and augment again by duplicating and scaling examples arbitrarily

# %% [markdown]
# ### TODO
#
# try translating data of 2nd scan forward and back to account for preliminary convergence of ICET- ideally, network should work with this as well
#
# augment data by randomizing order in which points appear
#
# View Convolution Filters in PCRnet

# %%
#setup - rememeber to switch to dnn kernel...
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import scipy.io as sio
import datetime

#need to have these two lines to work on my ancient 1060 3gb
#  https://stackoverflow.com/questions/43990046/tensorflow-blas-gemm-launch-failed
physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %matplotlib inline
# plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
# plt.rcParams['image.interpolation'] = 'nearest'
# plt.rcParams['image.cmap'] = 'gray'
# %matplotlib notebook

# %load_ext tensorboard

# for auto-reloading external modules
# %load_ext autoreload
# %autoreload 2
# %autosave 180
# Out:
# Autosaving every 180 seconds

# %%
#import training data
#toy data set
# d1 = np.loadtxt('training_data/scan1.txt')
# d2 = np.loadtxt('training_data/scan2.txt')
# gt = np.loadtxt('training_data/ground_truth.txt')

## slightly larger prism dataset
d1 = np.loadtxt("C:/Users/Derm/Desktop/big/pshift/scan1_10k.txt")
d2 = np.loadtxt("C:/Users/Derm/Desktop/big/pshift/scan2_10k.txt")
gt = np.loadtxt("C:/Users/Derm/Desktop/big/pshift/ground_truth_10k.txt")

# #combine two datasets
# d1 = np.append(d1, d1_2, axis = 0)
# d2 = np.append(d2, d2_2, axis = 0)
# gt = np.append(gt, gt_2, axis = 0)

points_per_sample = 25 #100 #25 #num pts per scan - defined in MatLab script
scan1 = tf.reshape(tf.convert_to_tensor(d1), [-1, points_per_sample, 3])
scan2 = tf.reshape(tf.convert_to_tensor(d2), [-1, points_per_sample, 3])
gt = tf.convert_to_tensor(gt)
# print(tf.shape(scan1))
# print(tf.shape(gt))

#split data into training and validation sets
tsplit = 0.95 #this fraction goes into training
ntrain = int(tsplit*tf.shape(scan1)[0].numpy())
x_train = tf.concat((scan1[:ntrain], scan2[:ntrain]), axis = 1)
x_test = tf.concat((scan1[ntrain:], scan2[ntrain:]), axis = 1)
y_train = gt[:ntrain]
y_test = gt[ntrain:]

# x_train = tf.reshape(x_train, [-1, 50, 1, 1, 1])
print(tf.shape(x_train))
# x_train = tf.reshape(x_train, [-1, 50, 3])

# print(x_train[0,0,:])
# Out:
# tf.Tensor([152000     50      3], shape=(3,), dtype=int32)

# %%
#train network
from network import Net
# from network import permNet as Net
# from network import PointNet as Net
# from network import PCRnet as Net
np.random.seed(1337)

runLen = 100

def scheduler(epoch, learning_rate):
#     part1 = 2*runLen//3
#     part2 = 5*runLen//6 #net1

    part1 = runLen//3
    part2 = 2*runLen//3 #net2

    if epoch < part1:
        learning_rate = 0.001
        return learning_rate
    if epoch >= part1 and epoch < part2:
        learning_rate = 0.00035
        return learning_rate
    if epoch >= part2:
        learning_rate = 0.00005
        return learning_rate

model = Net()
model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.005),
              loss = tf.keras.losses.MeanAbsoluteError()) #was MeanSquaredError()

summary = model.summary()
print(summary)
callback = tf.keras.callbacks.LearningRateScheduler(scheduler)

log_dir = "runs/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

trace = model.fit(x = x_train, y = y_train, batch_size = 64, epochs=runLen, verbose=1, 
                  validation_split = 0.2, shuffle=True, callbacks = [callback, tensorboard_callback])
#add to callback to use stepped learning rate
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50, 3)]           0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 3)             12
# _________________________________________________________________
# dense (Dense)                (None, 50, 64)            256
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 64)            256
# _________________________________________________________________
# dense_1 (Dense)              (None, 50, 128)           8320
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 50, 128)           512
# _________________________________________________________________
# dense_2 (Dense)              (None, 50, 256)           33024
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 2, 256)            0
# _________________________________________________________________
# tf_op_layer_Transpose (Tenso [(None, 256, 2)]          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 254, 32)           224
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 254, 32)           128
# _________________________________________________________________
# dense_3 (Dense)              (None, 254, 64)           2112
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 254, 64)           256
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 250, 32)           10272
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 250, 32)           128
# _________________________________________________________________
# dense_4 (Dense)              (None, 250, 64)           2112
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 250, 64)           256
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 81, 32)            16416
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 81, 32)            128
# _________________________________________________________________
# dense_5 (Dense)              (None, 81, 64)            2112
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 81, 64)            256
# _________________________________________________________________
# flatten (Flatten)            (None, 5184)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                331840
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 195
# _________________________________________________________________
# tf_op_layer_Mul (TensorFlowO [(None, 3)]               0
# =================================================================
# Total params: 409,071
# Trainable params: 407,977
# Non-trainable params: 1,094
# _________________________________________________________________
# None
# Epoch 1/100
#    1/1900 [..............................] - ETA: 0s - loss: 13.3488WARNING:tensorflow:From C:\Users\Derm\anaconda3\envs\dnn\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1900 [..............................] - ETA: 51s - loss: 15.1178WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_train_batch_end` time: 0.0489s). Check your callbacks.
# 1899/1900 [============================>.] - ETA: 0s - loss: 1.8960WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0010s vs `on_test_batch_end` time: 0.0020s). Check your callbacks.
# 1900/1900 [==============================] - 27s 14ms/step - loss: 1.8956 - val_loss: 1.3290
# Epoch 2/100
# 1900/1900 [==============================] - 26s 14ms/step - loss: 1.3257 - val_loss: 1.0136
# Epoch 3/100
# 1900/1900 [==============================] - 26s 14ms/step - loss: 1.2271 - val_loss: 0.9884
# Epoch 4/100
# 1900/1900 [==============================] - 26s 14ms/step - loss: 1.1750 - val_loss: 0.9834
# Epoch 5/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 1.1308 - val_loss: 0.8231
# Epoch 6/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 1.0881 - val_loss: 0.8539
# Epoch 7/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 1.0553 - val_loss: 0.8116
# Epoch 8/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 1.0279 - val_loss: 0.8298
# Epoch 9/100
# 1900/1900 [==============================] - 27s 14ms/step - loss: 1.0206 - val_loss: 0.6856
# Epoch 10/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9930 - val_loss: 0.7279
# Epoch 11/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9906 - val_loss: 0.6896
# Epoch 12/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9551 - val_loss: 0.6647
# Epoch 13/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9468 - val_loss: 0.6419
# Epoch 14/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9563 - val_loss: 0.6875
# Epoch 15/100
# 1900/1900 [==============================] - 25s 13ms/step - loss: 0.9214 - val_loss: 0.6342
# Epoch 16/100
# 1900/1900 [==============================] - 24s 13ms/step - loss: 0
100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7211 - val_loss: 0.4625
# Epoch 79/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7235 - val_loss: 0.4574
# Epoch 80/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7306 - val_loss: 0.4590
# Epoch 81/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7179 - val_loss: 0.4602
# Epoch 82/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7146 - val_loss: 0.4580
# Epoch 83/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7123 - val_loss: 0.4595
# Epoch 84/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7138 - val_loss: 0.4788
# Epoch 85/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7250 - val_loss: 0.4864
# Epoch 86/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7203 - val_loss: 0.4653
# Epoch 87/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7148 - val_loss: 0.4669
# Epoch 88/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7121 - val_loss: 0.4684
# Epoch 89/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7203 - val_loss: 0.4609
# Epoch 90/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7115 - val_loss: 0.4601
# Epoch 91/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7098 - val_loss: 0.4538
# Epoch 92/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7139 - val_loss: 0.4589
# Epoch 93/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7143 - val_loss: 0.4656
# Epoch 94/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7088 - val_loss: 0.4680
# Epoch 95/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7140 - val_loss: 0.4649
# Epoch 96/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7073 - val_loss: 0.4653
# Epoch 97/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7048 - val_loss: 0.4586
# Epoch 98/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7094 - val_loss: 0.4678
# Epoch 99/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7113 - val_loss: 0.4743
# Epoch 100/100
# 1900/1900 [==============================] - 22s 12ms/step - loss: 0.7137 - val_loss: 0.4639

# %%
fig0, ax0 = plt.subplots()
ax0.plot(trace.history['loss'], '-')
ax0.plot(trace.history['val_loss'], '-')
ax0.legend(['train', 'val'], loc='upper left')
ax0.set_xlabel('iteration')
ax0.set_ylabel('loss')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'loss')

# %%
# estimates = model.predict(x_train[0:100:16])
# print(estimates)
# print(y_train[0:100:16])

estimates = model.predict(x_test[0:100:16])
print("estimated translation x y z")
print(estimates)
print("actual translation x y z")
print(y_test[0:100:16])

err = y_test[0:100:16] - estimates
# err = y_train[0:100:16] - estimates

print("\n Error \n",err)

#MSE
print(tf.math.reduce_mean(tf.math.reduce_sum(err**2, axis = 1)/3))
# Out:
# estimated translation x y z
# [[-1.3249332e+01  4.2725959e+00  6.7388159e-01]
#  [ 7.1113248e+00  3.6508229e+00  3.8141120e-02]
#  [ 2.4746807e+01  8.8513365e+00 -1.5545377e-01]
#  [-3.6295595e+00  6.0782943e+00 -1.0116501e-01]
#  [-1.3063241e+00 -8.3545560e-01  7.4379710e-03]
#  [-6.9296160e+00 -2.7282372e-01  5.5199552e-01]
#  [-3.3750172e+00  2.0044596e+00 -5.2628270e-03]]
# actual translation x y z
# tf.Tensor(
# [[-17.74305906   5.950387     0.60246285]
#  [  7.34184976   3.9066601   -0.64926872]
#  [ 24.48157993   8.34772717   0.50683834]
#  [-10.36261673   6.84488045  -0.66800991]
#  [ -1.26811165  -1.16053617   0.08240707]
#  [ -7.28884097  -0.18830259   0.42038043]
#  [ -3.3454112    2.04865804   1.02036769]], shape=(7, 3), dtype=float64)
#
#  Error
#  tf.Tensor(
# [[-4.49372663  1.67779112 -0.07141874]
#  [ 0.23052497  0.25583722 -0.68740984]
#  [-0.26522716 -0.50360931  0.66229211]
#  [-6.73305721  0.76658617 -0.5668449 ]
#  [ 0.03821247 -0.32508057  0.0749691 ]
#  [-0.35922499  0.08452113 -0.13161509]
#  [ 0.02960597  0.04419842  1.02563052]], shape=(7, 3), dtype=float64)
# tf.Tensor(3.425306183968531, shape=(), dtype=float64)

# %%
#visualize results of network on test data
#2d plots (x and y only)
fig1, ax1 = plt.subplots()
n = 5010 #sample number (from x_test)
print(tf.shape(x_test))

c1 = np.array([x_test[n,:points_per_sample,0].numpy(), x_test[n,:points_per_sample,1].numpy(), x_test[n,:points_per_sample,2].numpy()])
c2 = np.array([x_test[n,points_per_sample:,0].numpy(), x_test[n,points_per_sample:,1].numpy(), x_test[n,points_per_sample:,2].numpy()])
ax1.scatter(c1[0,:], c1[1,:], color = [0.9, 0.3, 0.3], label = 'scan 1')
ax1.scatter(c2[0,:], c2[1,:], color = [0.5, 0.5, 0.9], label = 'scan 2')

# print(np.shape(x_test[n][None,:]))

inputs = x_test[n][None,:]
runlen = 3
for i in range(runlen):
    correction = 0.1*model.predict(inputs)[0] #show what the network thinks
#     correction = 0.1*y_test[n] #show actual solution
    c1 = np.array([c1[0,:] + correction[0], c1[1,:] + correction[1], c1[2,:] + correction[2]])
    inputs = np.append(c1, c2, axis = 1).T[None,:,:]
    moved = ax1.scatter(c1[0,:], c1[1,:], marker = 'x', color = [0., 0., 0., (i+1)/(runlen+1)],
                        label = 'scan 1 (translated) iter %i' %(i+1))

# moved = ax1.scatter(c1[0,:], c1[1,:], marker = 'x', color = [0.9, 0.3, 0.3, (i+2)/(runlen+2)],
#                         label = 'scan 1 (translated)')

ax1.set_title("estimated transformation = [ %f , %f, %f ]" %(correction[0], correction[1], correction[2]))
ax1.set_xlabel("X")
ax1.set_ylabel("Y")
ax1.legend(loc = 'best')
# Out:
# <img src="data:image/png;base64,..." width="640">
# tf.Tensor([8000   50    3], shape=(3,), dtype=int32)

# %%
#save network
# model.save("ffnet10k25.kmod")
model.save("Net.kmod")


#load network
# model = tf.keras.models.load_model("ffnet10k25.kmod")

# %%
#test random shuffle layer to enforce training on unordered data
#GOAL: randomize order of each sample in batch SEPRATELY 
#      (i.e. don't have same order for all elements of batch)

test = tf.constant([[1., 3., 4.], [2., 3., 5.], [6., 6., 6.], [0., 0., 0.]])#[None, :, :]
test = tf.Variable([test, 2*test])
print(test)

test = tf.transpose(test, [1,0,2])
test = tf.random.shuffle(test)
test = tf.transpose(test, [1,0,2])
print(test)

# %% [markdown]
# ### Top scores:
#
# #### 1k dataset
# 8.23 MSE with no parallelization (vel = [5, 5, 5])
#
# 4.2 MSE (vel = [5, 5, 0.01])
#
# 3.9 MSE - 50 sample points from each scan
#
# 3.34- maxpool on first/ second half, conv after
#
#
# #### 10k dataset
#
# 2.4 MSE 50 samples
#
# 1.05 MSE 25 samples -ffNet10k25.kmod

# %% [markdown]
# ### Notes
# From PointNet: Small rotations and gaussian noise can successfully augment models to increase training dataset
#
# Need to figure out a way to achieve permutation invariance
# Try transformer network i.e. "Attention is all you need"
# https://ai.googleblog.com/2021/11/permutation-invariant-neural-networks.html
#
# Can potentially use reflectance as 4th dimension(?)

# %%
8**3
